# %% [markdown]
# **Go to upper left menu -> Run - Run all cells**
#
# Running this notebook ensures that you have the desired versions of the packages.
#
# pip >= 22.2.2
# numpy >= 1.15
# matplotlib >= 3.5.3
# seaborn >= 0.11.0
# pandas >= 1.4.3
# openpyxl >= 3.0.10
# numexpr  >= 2.8.3
# scikit-Learn >= 1.1.2
# missingno >= 0.5.1
# statsmodels >= 0.13.2
# rgf-python >= 3.12.0
# xgboost >= 1.5.2
# nltk >= 3.7
# gensim >= 4.2.0
# html5lib >= 1.1
# pyldavis >= 3.3.1
# tensorflow >= 2.9.1
# tpot >= 0.11.7

# %%
# !pip install -U pip
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/pip/22.2.2/pip-22.2.2-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 3.3 MB/s
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-22.2.2

# %%
# !pip install -U numpy
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.9/site-packages (1.20.3)
# Collecting numpy
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/numpy/1.23.2/numpy-1.23.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 22.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.20.3
#     Not uninstalling numpy at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'numpy'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.11.4 requires pyspark>=2.1.0, which is not installed.
# scipy 1.7.1 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.2 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.23.2 which is incompatible.
# mleap 0.20.0 requires scikit-learn<0.23.0,>=0.22.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed numpy-1.23.2

# %%
# !pip install -U matplotlib
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: matplotlib in /databricks/python3/lib/python3.9/site-packages (3.4.3)
# Collecting matplotlib
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/matplotlib/3.5.3/matplotlib-3.5.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (21.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/fonttools/4.36.0/fonttools-4.36.0-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.4/950.4 kB 17.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: numpy>=1.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# Installing collected packages: fonttools, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.4.3
#     Not uninstalling matplotlib at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'matplotlib'. No files were found to uninstall.
# Successfully installed fonttools-4.36.0 matplotlib-3.5.3

# %%
# !pip install -U seaborn
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: seaborn in /databricks/python3/lib/python3.9/site-packages (0.11.2)
# Requirement already satisfied: numpy>=1.15 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from seaborn) (1.23.2)
# Requirement already satisfied: scipy>=1.0 in /databricks/python3/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: matplotlib>=2.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: pandas>=0.23 in /databricks/python3/lib/python3.9/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (21.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied: pytz>=2017.3 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.3)
# Collecting numpy>=1.15
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/numpy/1.22.4/numpy-1.22.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 18.9 MB/s eta 0:00:00
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.2
#     Uninstalling numpy-1.23.2:
#       Successfully uninstalled numpy-1.23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.11.4 requires pyspark>=2.1.0, which is not installed.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.22.4 which is incompatible.
# mleap 0.20.0 requires scikit-learn<0.23.0,>=0.22.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed numpy-1.22.4

# %%
# !pip install -U pandas
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.9/site-packages (1.3.4)
# Collecting pandas
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/pandas/1.4.3/pandas-1.4.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 17.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from pandas) (1.22.4)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.3.4
#     Not uninstalling pandas at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'pandas'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.11.4 requires pyspark>=2.1.0, which is not installed.
# mleap 0.20.0 requires scikit-learn<0.23.0,>=0.22.0, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed pandas-1.4.3

# %%
# !pip install -U openpyxl
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting openpyxl
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/openpyxl/3.0.10/openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.1/242.1 kB 4.4 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/et-xmlfile/1.1.0/et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.10

# %%
# !pip install -U numexpr
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting numexpr
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/numexpr/2.8.3/numexpr-2.8.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (380 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.5/380.5 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.13.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from numexpr) (1.22.4)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.9/site-packages (from numexpr) (21.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging->numexpr) (3.0.4)
# Installing collected packages: numexpr
# Successfully installed numexpr-2.8.3

# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: scikit-learn in /databricks/python3/lib/python3.9/site-packages (0.24.2)
# Collecting scikit-learn
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/scikit-learn/1.1.2/scikit_learn-1.1.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.8/30.8 MB 19.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn) (1.7.1)
# Requirement already satisfied: joblib>=1.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn) (1.0.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.2
#     Not uninstalling scikit-learn at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'scikit-learn'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mleap 0.20.0 requires scikit-learn<0.23.0,>=0.22.0, but you have scikit-learn 1.1.2 which is incompatible.
# Successfully installed scikit-learn-1.1.2

# %%
# !pip install -U missingno
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: missingno in /databricks/python3/lib/python3.9/site-packages (0.5.1)
# Requirement already satisfied: matplotlib in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from missingno) (3.5.3)
# Requirement already satisfied: numpy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from missingno) (1.22.4)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.9/site-packages (from missingno) (1.7.1)
# Requirement already satisfied: seaborn in /databricks/python3/lib/python3.9/site-packages (from missingno) (0.11.2)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->missingno) (21.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from matplotlib->missingno) (4.36.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->missingno) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->missingno) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->missingno) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib->missingno) (8.4.0)
# Requirement already satisfied: pandas>=0.23 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from seaborn->missingno) (1.4.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->missingno) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.23->seaborn->missingno) (2021.3)

# %%
# !pip install -U statsmodels
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: statsmodels in /databricks/python3/lib/python3.9/site-packages (0.12.2)
# Collecting statsmodels
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/statsmodels/0.13.2/statsmodels-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 14.0 MB/s eta 0:00:00
# Collecting packaging>=21.3
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/packaging/21.3/packaging-21.3-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: pandas>=0.25 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from statsmodels) (1.4.3)
# Requirement already satisfied: scipy>=1.3 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: patsy>=0.5.2 in /databricks/python3/lib/python3.9/site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in /databricks/python3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: packaging, statsmodels
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.0
#     Not uninstalling packaging at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'packaging'. No files were found to uninstall.
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.12.2
#     Not uninstalling statsmodels at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'statsmodels'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.11.4 requires pyspark>=2.1.0, which is not installed.
# Successfully installed packaging-21.3 statsmodels-0.13.2

# %%
# !pip install -U rgf-python
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting rgf-python
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/rgf-python/3.12.0/rgf_python-3.12.0-py3-none-manylinux1_x86_64.whl (757 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.8/757.8 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.18 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from rgf-python) (1.1.2)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.9/site-packages (from rgf-python) (1.0.1)
# Requirement already satisfied: numpy>=1.17.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from scikit-learn>=0.18->rgf-python) (1.22.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn>=0.18->rgf-python) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn>=0.18->rgf-python) (1.7.1)
# Installing collected packages: rgf-python
# Successfully installed rgf-python-3.12.0

# %%
# !pip install -U nltk
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: nltk in /databricks/python3/lib/python3.9/site-packages (3.6.5)
# Collecting nltk
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/nltk/3.7/nltk-3.7-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.9/site-packages (from nltk) (4.62.3)
# Requirement already satisfied: click in /databricks/python3/lib/python3.9/site-packages (from nltk) (8.0.3)
# Requirement already satisfied: regex>=2021.8.3 in /databricks/python3/lib/python3.9/site-packages (from nltk) (2021.8.3)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.9/site-packages (from nltk) (1.0.1)
# Installing collected packages: nltk
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.6.5
#     Not uninstalling nltk at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'nltk'. No files were found to uninstall.
# Successfully installed nltk-3.7

# %%
# !pip install -U gensim
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting gensim
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/gensim/4.2.0/gensim-4.2.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /databricks/python3/lib/python3.9/site-packages (from gensim) (5.2.1)
# Requirement already satisfied: scipy>=0.18.1 in /databricks/python3/lib/python3.9/site-packages (from gensim) (1.7.1)
# Requirement already satisfied: numpy>=1.17.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from gensim) (1.22.4)
# Installing collected packages: gensim
# Successfully installed gensim-4.2.0

# %%
# !pip install -U html5lib
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting html5lib
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/html5lib/1.1/html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.9/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in /databricks/python3/lib/python3.9/site-packages (from html5lib) (1.16.0)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %%
# !pip install -U pyldavis
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting pyldavis
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/pyldavis/3.3.1/pyLDAvis-3.3.1.tar.gz (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 7.0 MB/s eta 0:00:00
# done
# done
# done
# done
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.9/site-packages (from pyldavis) (1.7.1)
# Requirement already satisfied: numpy>=1.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from pyldavis) (1.22.4)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.9/site-packages (from pyldavis) (2.11.3)
# Requirement already satisfied: numexpr in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from pyldavis) (2.8.3)
# Collecting funcy
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/funcy/1.17/funcy-1.17-py2.py3-none-any.whl (33 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from pyldavis) (58.0.4)
# Requirement already satisfied: future in /databricks/python3/lib/python3.9/site-packages (from pyldavis) (0.18.2)
# Requirement already satisfied: pandas>=1.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from pyldavis) (1.4.3)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.9/site-packages (from pyldavis) (1.0.1)
# Requirement already satisfied: scikit-learn in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from pyldavis) (1.1.2)
# Requirement already satisfied: gensim in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from pyldavis) (4.2.0)
# Collecting sklearn
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/sklearn/0.0/sklearn-0.0.tar.gz (1.1 kB)
# done
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.2.0->pyldavis) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=1.2.0->pyldavis) (2021.3)
# Requirement already satisfied: smart-open>=1.8.1 in /databricks/python3/lib/python3.9/site-packages (from gensim->pyldavis) (5.2.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.9/site-packages (from jinja2->pyldavis) (2.0.1)
# Requirement already satisfied: packaging in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from numexpr->pyldavis) (21.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->pyldavis) (2.2.0)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=1.2.0->pyldavis) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging->numexpr->pyldavis) (3.0.4)
# Building wheels for collected packages: pyldavis, sklearn
# done
#   Created wheel for pyldavis: filename=pyLDAvis-3.3.1-py2.py3-none-any.whl size=136897 sha256=36e6d379a675c8a475fbef08fc3568303092f3e925545c05c9863250d8b6f1b2
#   Stored in directory: /root/.cache/pip/wheels/3a/eb/28/f33b3c38bd733e3d6b9ca40599af933de2dff68e42c211ed60
# done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1309 sha256=8551adf9356a76d1a305243195906f2cb290ffa97fb3f52f45b1f3d060d8423a
#   Stored in directory: /root/.cache/pip/wheels/73/b6/ac/ff9b7dc0d48d7a647d7c8cbad0def09f43e3a0f11a8abb355c
# Successfully built pyldavis sklearn
# Installing collected packages: funcy, sklearn, pyldavis
# Successfully installed funcy-1.17 pyldavis-3.3.1 sklearn-0.0

# %%
# !pip install -U tensorflow
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting tensorflow
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/tensorflow/2.9.1/tensorflow-2.9.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.7 MB)
#      ━━━━━━━━━━━━━━━╺[9
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.7/511.7 MB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.1.0)
# Collecting tensorboard<2.10,>=2.9
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/tensorboard/2.9.1/tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (0.25.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: packaging in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: astunparse>=1.6.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.44.0)
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/tensorflow-estimator/2.9.0/tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: google-pasta>=0.1.1 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/keras/2.9.0/keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: absl-py>=1.0.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: numpy>=1.20 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (3.10.0.2)
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/gast/0.4.0/gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: h5py>=2.9.0 in /databricks/python3/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Collecting flatbuffers<2,>=1.12
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/flatbuffers/1.12/flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /databricks/python3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: markdown>=2.6.8 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /databricks/python3/lib/python3.9/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging->tensorflow) (3.0.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /databricks/python3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /databricks/python3/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Installing collected packages: keras, flatbuffers, tensorflow-estimator, gast, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.8.0
#     Not uninstalling keras at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'keras'. No files were found to uninstall.
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Not uninstalling flatbuffers at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'flatbuffers'. No files were found to uninstall.
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Not uninstalling tensorflow-estimator at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'tensorflow-estimator'. No files were found to uninstall.
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Not uninstalling gast at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'gast'. No files were found to uninstall.
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Not uninstalling tensorboard at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'tensorboard'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.8.0 requires keras<2.9,>=2.8.0rc0, but you have keras 2.9.0 which is incompatible.
# tensorflow-cpu 2.8.0 requires tensorboard<2.9,>=2.8, but you have tensorboard 2.9.1 which is incompatible.
# Successfully installed flatbuffers-1.12 gast-0.4.0 keras-2.9.0 tensorboard-2.9.1 tensorflow-2.9.1 tensorflow-estimator-2.9.0

# %%
# !pip install -U tpot
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Collecting tpot
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/tpot/0.11.7/TPOT-0.11.7-py3-none-any.whl (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.36.1 in /databricks/python3/lib/python3.9/site-packages (from tpot) (4.62.3)
# Requirement already satisfied: xgboost>=1.1.0 in /databricks/python3/lib/python3.9/site-packages (from tpot) (1.5.2)
# Requirement already satisfied: joblib>=0.13.2 in /databricks/python3/lib/python3.9/site-packages (from tpot) (1.0.1)
# Requirement already satisfied: numpy>=1.16.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from tpot) (1.22.4)
# Collecting stopit>=1.1.1
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/stopit/1.1.2/stopit-1.1.2.tar.gz (18 kB)
# done
# Collecting deap>=1.2
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/deap/1.3.3/deap-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from tpot) (1.1.2)
# Requirement already satisfied: scipy>=1.3.1 in /databricks/python3/lib/python3.9/site-packages (from tpot) (1.7.1)
# Requirement already satisfied: pandas>=0.24.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from tpot) (1.4.3)
# Collecting update-checker>=0.16
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/update-checker/0.18.0/update_checker-0.18.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.24.2->tpot) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas>=0.24.2->tpot) (2021.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn>=0.22.0->tpot) (2.2.0)
# Requirement already satisfied: requests>=2.3.0 in /databricks/python3/lib/python3.9/site-packages (from update-checker>=0.16->tpot) (2.26.0)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.2->tpot) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.3.0->update-checker>=0.16->tpot) (2021.10.8)
# Building wheels for collected packages: stopit
# done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11952 sha256=cf9af726de6e878413401221fc15d8bb48e6659747b4f879d4392f79f5f52acb
#   Stored in directory: /root/.cache/pip/wheels/ee/4d/b7/b84b55fdc0fb2e1a74746700a07cc321852c1d91fbd6f7ef48
# Successfully built stopit
# Installing collected packages: stopit, deap, update-checker, tpot
# Successfully installed deap-1.3.3 stopit-1.1.2 tpot-0.11.7 update-checker-0.18.0

# %%
# !pip install -U xgboost
# Out:
# Looking in indexes: https://nexus.rbinternational.corp/nexus/repository/aaws-pypi-host/simple, https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/simple
# Requirement already satisfied: xgboost in /databricks/python3/lib/python3.9/site-packages (1.5.2)
# Collecting xgboost
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nexus.rbinternational.corp', port=443): Read timed out. (read timeout=15)")': /nexus/repository/pypi-proxy/packages/xgboost/1.6.2/xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nexus.rbinternational.corp', port=443): Read timed out. (read timeout=15)")': /nexus/repository/pypi-proxy/packages/xgboost/1.6.2/xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nexus.rbinternational.corp', port=443): Read timed out. (read timeout=15)")': /nexus/repository/pypi-proxy/packages/xgboost/1.6.2/xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl
#   WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='nexus.rbinternational.corp', port=443): Read timed out. (read timeout=15)")': /nexus/repository/pypi-proxy/packages/xgboost/1.6.2/xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl
#   Downloading https://nexus.rbinternational.corp/nexus/repository/pypi-proxy/packages/xgboost/1.6.2/xgboost-1.6.2-py3-none-manylinux2014_x86_64.whl (255.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 255.9/255.9 MB 966.7 kB/s eta 0:00:00
# Requirement already satisfied: numpy in /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877/lib/python3.9/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.9/site-packages (from xgboost) (1.7.1)
# Installing collected packages: xgboost
#   Attempting uninstall: xgboost
#     Found existing installation: xgboost 1.5.2
#     Not uninstalling xgboost at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-148e4a81-8018-4cc7-ae44-576c352ea877
#     Can't uninstall 'xgboost'. No files were found to uninstall.
# Successfully installed xgboost-1.6.2
